# %%
# %cd /content
# !rm -rf GFPGAN
# !git clone https://github.com/TencentARC/GFPGAN.git
# %cd GFPGAN

# Set up the environment
# Install basicsr - https://github.com/xinntao/BasicSR
# We use BasicSR for both training and inference
# !pip install basicsr
# Install facexlib - https://github.com/xinntao/facexlib
# We use face detection and face restoration helper in the facexlib package
# !pip install facexlib
# Install other depencencies
# !pip install -r requirements.txt
# !python setup.py develop
# !pip install realesrgan  # used for enhancing the background (non-face) regions
# Download the pre-trained model
# !wget https://github.com/TencentARC/GFPGAN/releases/download/v0.2.0/GFPGANCleanv1-NoCE-C2.pth -P experiments/pretrained_models
# Now we use the V1.3 model for the demo
#!wget https://github.com/TencentARC/GFPGAN/releases/download/v1.3.0/GFPGANv1.3.pth -P experiments/pretrained_models
# Out:
# [WinError 2] The system cannot find the file specified: '/content'
# c:\Users\vhema\Desktop\open-source\MuseTalk
# 'rm' is not recognized as an internal or external command,
# operable program or batch file.
# c:\Users\vhema\Desktop\open-source\MuseTalk\GFPGAN
# fatal: destination path 'GFPGAN' already exists and is not an empty directory.
# Requirement already satisfied: basicsr in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (1.4.2)
# Requirement already satisfied: addict in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from basicsr) (2.4.0)
# Requirement already satisfied: future in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from basicsr) (1.0.0)
# Requirement already satisfied: lmdb in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from basicsr) (1.5.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from basicsr) (1.26.3)
# Requirement already satisfied: opencv-python in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from basicsr) (4.10.0.84)
# Requirement already satisfied: Pillow in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from basicsr) (10.2.0)
# Requirement already satisfied: pyyaml in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from basicsr) (6.0.2)
# Requirement already satisfied: requests in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from basicsr) (2.32.3)
# Requirement already satisfied: scikit-image in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from basicsr) (0.25.0)
# Requirement already satisfied: scipy in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from basicsr) (1.14.1)
# Requirement already satisfied: tb-nightly in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from basicsr) (2.19.0a20241229)
# Requirement already satisfied: torch>=1.7 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from basicsr) (2.5.0+cu118)
# Requirement already satisfied: torchvision in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from basicsr) (0.20.0+cu118)
# Requirement already satisfied: tqdm in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from basicsr) (4.66.5)
# Requirement already satisfied: yapf in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from basicsr) (0.43.0)
# Requirement already satisfied: filelock in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from torch>=1.7->basicsr) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from torch>=1.7->basicsr) (4.12.2)
# Requirement already satisfied: networkx in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from torch>=1.7->basicsr) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from torch>=1.7->basicsr) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from torch>=1.7->basicsr) (2024.2.0)
# Requirement already satisfied: setuptools in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from torch>=1.7->basicsr) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from torch>=1.7->basicsr) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from sympy==1.13.1->torch>=1.7->basicsr) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from requests->basicsr) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from requests->basicsr) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from requests->basicsr) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from requests->basicsr) (2024.12.14)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from scikit-image->basicsr) (2.36.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from scikit-image->basicsr) (2024.12.12)
# Requirement already satisfied: packaging>=21 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from scikit-image->basicsr) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from scikit-image->basicsr) (0.4)
# Requirement already satisfied: absl-py>=0.4 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from tb-nightly->basicsr) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from tb-nightly->basicsr) (1.68.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from tb-nightly->basicsr) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from tb-nightly->basicsr) (5.29.2)
# Requirement already satisfied: six>1.9 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from tb-nightly->basicsr) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from tb-nightly->basicsr) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from tb-nightly->basicsr) (3.1.3)
# Requirement already satisfied: colorama in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from tqdm->basicsr) (0.4.6)
# Requirement already satisfied: platformdirs>=3.5.1 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from yapf->basicsr) (4.3.6)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from werkzeug>=1.0.1->tb-nightly->basicsr) (2.1.5)
# Requirement already satisfied: facexlib in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (0.3.0)
# Requirement already satisfied: filterpy in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from facexlib) (1.4.5)
# Requirement already satisfied: numba in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from facexlib) (0.60.0)
# Requirement already satisfied: numpy in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from facexlib) (1.26.3)
# Requirement already satisfied: opencv-python in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from facexlib) (4.10.0.84)
# Requirement already satisfied: Pillow in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from facexlib) (10.2.0)
# Requirement already satisfied: scipy in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from facexlib) (1.14.1)
# Requirement already satisfied: torch in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from facexlib) (2.5.0+cu118)
# Requirement already satisfied: torchvision in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from facexlib) (0.20.0+cu118)
# Requirement already satisfied: tqdm in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from facexlib) (4.66.5)
# Requirement already satisfied: matplotlib in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from filterpy->facexlib) (3.9.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from numba->facexlib) (0.43.0)
# Requirement already satisfied: filelock in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from torch->facexlib) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from torch->facexlib) (4.12.2)
# Requirement already satisfied: networkx in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from torch->facexlib) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from torch->facexlib) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from torch->facexlib) (2024.2.0)
# Requirement already satisfied: setuptools in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from torch->facexlib) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from torch->facexlib) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from sympy==1.13.1->torch->facexlib) (1.3.0)
# Requirement already satisfied: colorama in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from tqdm->facexlib) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from jinja2->torch->facexlib) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->filterpy->facexlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->filterpy->facexlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->filterpy->facexlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->filterpy->facexlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->filterpy->facexlib) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->filterpy->facexlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->filterpy->facexlib) (2.9.0)
# Requirement already satisfied: six>=1.5 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from python-dateutil>=2.7->matplotlib->filterpy->facexlib) (1.16.0)
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# python: can't open file 'c:\\Users\\vhema\\Desktop\\open-source\\MuseTalk\\gfpgan\\setup.py': [Errno 2] No such file or directory
# ERROR: Invalid requirement: '#': Expected package name at the start of dependency specifier
#     #
#     ^
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# *   First Run this cell
#
# *   Once you've run the cell , you can see that a folder named "videos" will be created inside the GFPGAN folder
#
#
# *   Just drag and drop any number of videos from your computer and place them inside the "videos" folder. (videos you want to upscale)

# %%
import os
#from google.colab import files
import shutil

upload_folder = 'upload'
result_folder = 'results'
video_folder = 'videos'
video_result_folder = 'results_videos'
video_mp4_result_folder = 'results_mp4_videos'

if os.path.isdir(upload_folder):
  print(upload_folder+" exists")
else :
  os.mkdir(upload_folder)

if os.path.isdir(video_folder):
  print(video_folder+" exists")
else :
  os.mkdir(video_folder)

if os.path.isdir(video_result_folder):
  print(video_result_folder+" exists")
else :
  os.mkdir(video_result_folder)

if os.path.isdir(video_mp4_result_folder):
  print(video_mp4_result_folder+" exists")
else :
  os.mkdir(video_mp4_result_folder)

if os.path.isdir(result_folder):
  print(result_folder+" exists")

else :
  os.mkdir(result_folder)
# Out:
# results exists

# %%
pip install torch==2.2.0 torchvision==0.17.0
# Out:
# Requirement already satisfied: torch==2.2.0 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (2.2.0)
# Requirement already satisfied: torchvision==0.17.0 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (0.17.0)
# Requirement already satisfied: filelock in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from torch==2.2.0) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from torch==2.2.0) (4.12.2)
# Requirement already satisfied: sympy in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from torch==2.2.0) (1.13.1)
# Requirement already satisfied: networkx in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from torch==2.2.0) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from torch==2.2.0) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from torch==2.2.0) (2024.2.0)
# Requirement already satisfied: numpy in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from torchvision==0.17.0) (1.26.3)
# Requirement already satisfied: requests in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from torchvision==0.17.0) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from torchvision==0.17.0) (10.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from jinja2->torch==2.2.0) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from requests->torchvision==0.17.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from requests->torchvision==0.17.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from requests->torchvision==0.17.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from requests->torchvision==0.17.0) (2024.12.14)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\vhema\anaconda3\envs\pytorch\lib\site-packages (from sympy->torch==2.2.0) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import glob
from os.path import isfile, join
import subprocess
from IPython.display import clear_output  

# assign directory
directory = r'C:\Users\vhema\Desktop\open-source\MuseTalk\gfpgan\videos' #PATH_WITH_INPUT_VIDEOS
zee = 0

#deletes frames from previous video
for f in os.listdir(upload_folder): 
    os.remove(os.path.join(upload_folder, f))

#deletes upscaled frames from previous video
#for f in os.listdir('results/restored_imgs'): 
#    os.remove(os.path.join('results/restored_imgs', f))

#clearing previous .avi files
for f in os.listdir(video_result_folder): 
    os.remove(os.path.join(video_result_folder, f))
     
#clearing .mp4 result files
for f in os.listdir(video_mp4_result_folder): 
    os.remove(os.path.join(video_mp4_result_folder, f))


def convert_frames_to_video(pathIn,pathOut,fps):
    frame_array = []
    files = [f for f in os.listdir(pathIn) if isfile(join(pathIn, f))]
    #for sorting the file names properly
    files.sort(key = lambda x: int(x[5:-4]))
    size2 = (0,0)

    for i in range(len(files)):
        filename=pathIn + files[i]
        #reading each files
        img = cv2.imread(filename)
        height, width, layers = img.shape
        size = (width,height)
        size2 = size
        print(filename)
        #inserting the frames into an image array
        frame_array.append(img)
    out = cv2.VideoWriter(pathOut,cv2.VideoWriter_fourcc(*'DIVX'), fps, size2)
    for i in range(len(frame_array)):
        # writing to a image array
        out.write(frame_array[i])
    out.release()
    
        
for filename in os.listdir(directory):
    
    f = os.path.join(directory, filename)
    # checking if it is a file
    if os.path.isfile(f):
      
      
      print("PROCESSING :"+str(f)+"\n")
      # Read the video from specified path
    
      #video to frames
      cam = cv2.VideoCapture(str(f))

      try:

          # PATH TO STORE VIDEO FRAMES
          if not os.path.exists('/content/gfpgan/upload'):
              os.makedirs('/content/gfpgan/upload')

      # if not created then raise error
      except OSError:
          print ('Error: Creating directory of data')

      # frame
      currentframe = 0

      #clear all folders


      #deletes upscaled frames from previous video
      #for f in os.listdir(result_folder):
      #  os.remove(os.path.join(result_folder, f))      
      



      while(True):

          # reading from frame
          ret,frame = cam.read()

          if ret:
              # if video is still left continue creating images
              name = '/content/gfpgan/upload/frame' + str(currentframe) + '.jpg'

              # writing the extracted images
              cv2.imwrite(name, frame)


                # increasing counter so that it will
                # show how many frames are created
              currentframe += 1
              print(currentframe)
          else:
              #deletes all the videos you uploaded for upscaling
              #for f in os.listdir(video_folder):
              #  os.remove(os.path.join(video_folder, f)) 

              break
      
        # Release all space and windows once done
      cam.release()
      cv2.destroyAllWindows()
      
      #apply super-resolution on all frames of a video
      #scale factor is by 3.5x  

      #in the line below '2' stands for upscaling by factor of 2
      # !python inference_gfpgan.py -i upload -o results -v 1.2 -s 2 --bg_upsampler realesrgan

      #after upscaling just delete the source frames
      for f in os.listdir(upload_folder): 
          os.remove(os.path.join(upload_folder, f))     

      '''
      #rename all frames in "results" to remove the 'out' substring from the processing results
      paths = (os.path.join(root, filename)
              for root, _, filenames in os.walk('/content/GFPGAN/results')
              for filename in filenames)
      for path in paths:
          newname = path.replace('_out', '')
          if newname != path:
              os.rename(path, newname)      
      '''

      #convert super res frames to .avi  
      pathIn = '/content/gfpgan/results/restored_imgs/'
      if not os.path.exists(pathIn):
          os.makedirs(pathIn)

      zee = zee+1
      fName = "video"+str(zee)  
      filenameVid = f"{fName}.avi"
        
      pathOut = "/content/gfpgan/results_videos/"+filenameVid

      fps = 25.0 #change this to FPS of your source video

      convert_frames_to_video(pathIn, pathOut, fps)      

      #after processing frames converted to .avi video , delete upscaled frames from previous video
      for f in os.listdir('results/restored_imgs'): 
          os.remove(os.path.join('results/restored_imgs', f))

      #convert .avi to .mp4
      src = '/content/gfpgan/results_videos/'
      dst = '/content/gfpgan/results_mp4_videos/'

      for root, dirs, filenames in os.walk(src, topdown=False):
          #print(filenames)
          for filename in filenames:
              print('[INFO] 1',filename)
              try:
                  _format = ''
                  if ".flv" in filename.lower():
                      _format=".flv"
                  if ".mp4" in filename.lower():
                      _format=".mp4"
                  if ".avi" in filename.lower():
                      _format=".avi"
                  if ".mov" in filename.lower():
                      _format=".mov"

                  inputfile = os.path.join(root, filename)
                  print('[INFO] 1',inputfile)
                  outputfile = os.path.join(dst, filename.lower().replace(_format, ".mp4"))
                  subprocess.call(['ffmpeg', '-i', inputfile, outputfile])  
              except:
                  print("An exception occurred")        
  
      clear_output(wait=True)

      #clearing previous .avi files
      for f in os.listdir(video_result_folder): 
          os.remove(os.path.join(video_result_folder, f))

      #deletes frames from previous video
      #for f in os.listdir(upload_folder):
      #  os.remove(os.path.join(upload_folder, f))

        

      # if it is out of memory, try to use the `--tile` option
# We upsample the image with the scale factor X3.5

# Arguments
# -n, --model_name: Model names
# -i, --input: input folder or image
# --outscale: Output scale, can be arbitrary scale factore.
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import cv2
#       2 import numpy as np
#       3 import glob
#
# ModuleNotFoundError: No module named 'cv2'

# %% [markdown]
# # 3. Inference (Please READ)
#
#
#
# *   Then run this cell , it will take a good amount of time depending on the length of your video and how many videos you want to upscale
#
# *   Once the upscaling process is complete , you can find your upscaled video results , under the "results_mp4_videos" folder.
#
#
#
# *   By default the video is upscaled to a 25fps format,  in case you want to change that , it can be changed within the cell below ,
# change the "fps" variable. (Can be found  towards the end part of the code section.)

# %% [markdown]
# # 4. Download Results
#
#
#
# *   All your upscaled .mp4 files will be inside the results_mp4_videos folder (inside GFPGAN folder)
#
#
# *   You can right click on the needed file and download it from there.

# %% [markdown]
# # 5. Run this cell after the batch of videos have been upscaled
# # (WARNING : Deletes processed data)
#
#
#
# *   IMPORTANT : Read the comments inside the code section , because this DELETES previous frames and videos

# %%
#deletes frames from previous video
for f in os.listdir(upload_folder):
    os.remove(os.path.join(upload_folder, f))

#deletes upscaled frames from previous video
for f in os.listdir('results/restored_imgs'):
    os.remove(os.path.join('results/restored_imgs', f))

#deletes all the videos you uploaded for upscaling
for f in os.listdir(video_folder):
    os.remove(os.path.join(video_folder, f))

#clearing previous .avi files
for f in os.listdir(video_result_folder):
    os.remove(os.path.join(video_result_folder, f))

#clearing .mp4 result files
for f in os.listdir(video_mp4_result_folder):
    os.remove(os.path.join(video_mp4_result_folder, f))
